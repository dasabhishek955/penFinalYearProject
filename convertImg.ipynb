# %%
import cv2
import os
import glob
from google.colab.patches import cv2_imshow

i=1032
# for file in glob.glob("/content/drive/MyDrive/Project /*.*"):
#   img=cv2.imread(file)
#   img=cv2.resize(img,(640,640))
#   cv2.imwrite(f"/content/drive/MyDrive/640*640Img/{i}.png",img)
#   i+=1
print(i)
for file in glob.glob("/content/drive/MyDrive/Hemanta /Photo/*.*"):
  img=cv2.imread(file)
  img=cv2.resize(img,(640,640))
  cv2.imwrite(f"/content/drive/MyDrive/640*640Img/{i}.png",img)
  i+=1
print(i)
# Out:
# 1032
# 1433
